# %% [markdown]
# # 노선결정

# %%
import pandas as pd
df = pd.read_csv('./data_getonoffs/2019_getonoffs_per_line_stop_time(09).csv', encoding='cp949')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      사용년월      노선ID 노선번호             노선명  표준버스정류장ID 버스정류장ARS번호   역ID  \
# 0  201909  11110001  100  100번(하계동~용산구청)  100000003      01003  7197
# 1  201909  11110001  100  100번(하계동~용산구청)  101000057      02156  8839
# 2  201909  11110001  100  100번(하계동~용산구청)  101000060      02159  8864
# 3  201909  11110001  100  100번(하계동~용산구청)  102000173      03267  8878
# 4  201909  11110001  100  100번(하계동~용산구청)  101000061      02160  8881
#
#             역명  00시승차총승객수  00시하차총승객수  ...  19시하차총승객수  20시승차총승객수  20시하차총승객수  \
# 0    명륜3가.성대입구          2          1  ...        183        213        143
# 1   을지로입구.로얄호텔        190         27  ...         82        305         44
# 2  을지로2가.파인에빈뉴         90         13  ...         65        313         32
# 3      서빙고역교차로          1          0  ...         49         16         33
# 4        을지로3가          2          2  ...        319        168        230
#
#    21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  23시하차총승객수      등록일자
# ...

# %%
total_lines = df['노선ID'].unique()

# %%
total_lines
# Out:
# array([11110001, 11110002, 11110003, 11110005, 11110006, 11110007,
#        11110009, 11110010, 11110011, 11110012, 11110013, 11110014,
#        11110015, 11110016, 11110017, 11110018, 11110019, 11110020,
#        11110021, 11110022, 11110024, 11110027, 11110028, 11110030,
#        11110031, 11110032, 11110034, 11110035, 11110037, 11110038,
#        11110039, 11110044, 11110045, 11110046, 11110048, 11110049,
#        11110050, 11110052, 11110053, 11110054, 11110055, 11110056,
#        11110057, 11110058, 11110059, 11110060, 11110061, 11110062,
#        11110063, 11110065, 11110066, 11110067, 11110068, 11110069,
#        11110070, 11110071, 11110072, 11110073, 11110074, 11110076,
#        11110077, 11110078, 11110084, 11110085, 11110088, 11110090,
#        11110095, 11110096, 11110097, 11110099, 11110113, 11110115,
#        11110116, 11110117, 11110119, 11110121, 11110125, 11110126,
#        11110131, 11110133, 11110135, 11110136, 11110137, 11110139,
# ...

# %%
stops_in_line = {}
for line_id in total_lines:
    stops_in_line[line_id] = len(df[df['노선명'].str.contains('은평01')])
    
stops_in_line
# Out:
# {11110001: 14,
#  11110002: 14,
#  11110003: 14,
#  11110005: 14,
#  11110006: 14,
#  11110007: 14,
#  11110009: 14,
#  11110010: 14,
#  11110011: 14,
#  11110012: 14,
#  11110013: 14,
#  11110014: 14,
#  11110015: 14,
#  11110016: 14,
#  11110017: 14,
#  11110018: 14,
#  11110019: 14,
#  11110020: 14,
#  11110021: 14,
#  11110022: 14,
#  11110024: 14,
#  11110027: 14,
#  11110028: 14,
#  11110030: 14,
#  11110031: 14,
#  11110032: 14,
#  11110034: 14,
#  11110035: 14,
#  11110037: 14,
#  11110038: 14,
#  11110039: 14,
#  11110044: 14,
#  11110045: 14,
#  11110046: 14,
#  11110048: 14,
#  11110049: 14,
#  11110050: 14,
#  11110052: 14,
#  11110053: 14,
#  11110054: 14,
#  11110055: 14,
#  11110056: 14,
#  11110057: 14,
#  11110058: 14,
#  11110059: 14,
#  11110060: 14,
#  11110061: 14,
#  11110062: 14,
#  11110063: 14,
#  11110065: 14,
#  11110066: 14,
#  11110067: 14,
#  11110068: 14,
#  11110069: 14,
#  11110070: 14,
#  11110071: 14,
#  11110072: 14,
#  11110073: 14,
# ...

# %%
for i in df.index:
    line_name = df['노선번호'][i]
    
    if '은평01' in line_name:
        print(df['노선ID'][i])
        break
# Out:
# 11110712

# %%
line_w_stops = sorted(stops_in_line.items(), key=lambda x: x[1])
line_w_stops[:30]
# Out:
# [(11110001, 14),
#  (11110002, 14),
#  (11110003, 14),
#  (11110005, 14),
#  (11110006, 14),
#  (11110007, 14),
#  (11110009, 14),
#  (11110010, 14),
#  (11110011, 14),
#  (11110012, 14),
#  (11110013, 14),
#  (11110014, 14),
#  (11110015, 14),
#  (11110016, 14),
#  (11110017, 14),
#  (11110018, 14),
#  (11110019, 14),
#  (11110020, 14),
#  (11110021, 14),
#  (11110022, 14),
#  (11110024, 14),
#  (11110027, 14),
#  (11110028, 14),
#  (11110030, 14),
#  (11110031, 14),
#  (11110032, 14),
#  (11110034, 14),
#  (11110035, 14),
#  (11110037, 14),
#  (11110038, 14)]

# %%
df[df['노선명'].str.contains('6632')]
# Out:
#          사용년월      노선ID  노선번호                 노선명  표준버스정류장ID 버스정류장ARS번호  \
# 11849  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000123      16220
# 11850  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000071      16168
# 11851  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000061      16158
# 11852  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000062      16159
# 11853  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000009      16105
# ...       ...       ...   ...                 ...        ...        ...
# 11910  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000163      16260
# 11911  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000073      16170
# 11912  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000070      16167
# 11913  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000004      16004
# 11914  201909  11110291  6632  6632번(강서공영차고지~당산역)  115000320      16434
#
#            역ID            역명  00시승차총승객수  00시하차총승객수  ...  19시하차총승객수  20시승차총승객수  \
# ...

# %%
df_candidate = df[df['노선ID']==11110712]
df_candidate.head()
# Out:
#          사용년월      노선ID  노선번호             노선명  표준버스정류장ID 버스정류장ARS번호      역ID  \
# 24726  201909  11110712  은평01  은평01(연신내역~석광사)  111900010      12750  9009785
# 24727  201909  11110712  은평01  은평01(연신내역~석광사)  111900012      12733  9009788
# 24728  201909  11110712  은평01  은평01(연신내역~석광사)  111900014      12725  9009790
# 24729  201909  11110712  은평01  은평01(연신내역~석광사)  111900048      12573  9009892
# 24730  201909  11110712  은평01  은평01(연신내역~석광사)  111900051      12568  9009909
#
#              역명  00시승차총승객수  00시하차총승객수  ...  19시하차총승객수  20시승차총승객수  20시하차총승객수  \
# 24726  연갈현공판장후문          8          4  ...        227         79        106
# 24727  청구성심병원후문          5          7  ...         56         24         23
# 24728  연신내역6번출구        280         36  ...        244       2558        293
# 24729       석광사          3        204  ...       1398         90       1027
# 24730      미니마트          0         47  ...        471         52        446
#
# ...

# %%
df_psngr = df_candidate
len(df_psngr)
# Out:
# 14

# %%
df_psngr['표준버스정류장ID'].unique()
# Out:
# array([111900010, 111900012, 111900014, 111900048, 111900051, 111900055,
#        111900061, 111900064, 111900082, 111900086, 111900091, 111900096,
#        111001109], dtype=int64)

# %%
df_psngr['ARS-ID'] = df_psngr['버스정류장ARS번호']
# Out:
# c:\users\sewook kim\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_psngr
# Out:
#          사용년월      노선ID  노선번호             노선명  표준버스정류장ID 버스정류장ARS번호      역ID  \
# 24726  201909  11110712  은평01  은평01(연신내역~석광사)  111900010      12750  9009785
# 24727  201909  11110712  은평01  은평01(연신내역~석광사)  111900012      12733  9009788
# 24728  201909  11110712  은평01  은평01(연신내역~석광사)  111900014      12725  9009790
# 24729  201909  11110712  은평01  은평01(연신내역~석광사)  111900048      12573  9009892
# 24730  201909  11110712  은평01  은평01(연신내역~석광사)  111900051      12568  9009909
# 24731  201909  11110712  은평01  은평01(연신내역~석광사)  111900055      12563  9009921
# 24732  201909  11110712  은평01  은평01(연신내역~석광사)  111900061      12558  9009944
# 24733  201909  11110712  은평01  은평01(연신내역~석광사)  111900064      12553  9009948
# 24734  201909  11110712  은평01  은평01(연신내역~석광사)  111900082      12529  9009981
# 24735  201909  11110712  은평01  은평01(연신내역~석광사)  111900086      12523  9009985
# 24736  201909  11110712  은평01  은평01(연신내역~석광사)  111900091      12517  9009994
# ...

# %%
df_psngr = df_psngr.drop(24739)

# %%
df_psngr.dtypes
# Out:
# 사용년월           int64
# 노선ID           int64
# 노선번호          object
# 노선명           object
# 표준버스정류장ID      int64
# 버스정류장ARS번호    object
# 역ID            int64
# 역명            object
# 00시승차총승객수      int64
# 00시하차총승객수      int64
# 1시승차총승객수       int64
# 1시하차총승객수       int64
# 2시승차총승객수       int64
# 2시하차총승객수       int64
# 3시승차총승객수       int64
# 3시하차총승객수       int64
# 4시승차총승객수       int64
# 4시하차총승객수       int64
# 5시승차총승객수       int64
# 5시하차총승객수       int64
# 6시승차총승객수       int64
# 6시하차총승객수       int64
# 7시승차총승객수       int64
# 7시하차총승객수       int64
# 8시승차총승객수       int64
# 8시하차총승객수       int64
# 9시승차총승객수       int64
# 9시하차총승객수       int64
# 10시승차총승객수      int64
# 10시하차총승객수      int64
# 11시승차총승객수      int64
# 11시하차총승객수      int64
# 12시승차총승객수      int64
# 12시하차총승객수      int64
# 13시승차총승객수      int64
# 13시하차총승객수      int64
# 14시승차총승객수      int64
# 14시하차총승객수      int64
# 15시승차총승객수      int64
# 15시하차총승객수      int64
# 16시승차총승객수      int64
# 16시하차총승객수      int64
# 17시승차총승객수      int64
# ...

# %% [markdown]
# # 노선별 정류장 정보

# %% [markdown]
# import pandas as pd
# df_lines = pd.read_excel('./data_line/20190124_bus_lines.xls')

# %% [markdown]
# df_lines.to_csv('./data_line/20190124_bus_lines.csv')

# %% [markdown]
# del df_lines

# %%
import pandas as pd
df_lines = pd.read_csv('./data_line/20190124_bus_lines.csv', encoding='cp949')

# %%
df_lines.head()
# Out:
#         노선ID   노선명  순번       구간ID      정류소ID  ARS-ID        정류소명         X좌표  \
# 0  100100124  0017   1          0  102000271    3689     청암자이아파트  126.946517
# 1  100100124  0017   2  102700549  102000204    3298  청암동강변삼성아파트  126.949304
# 2  100100124  0017   3  102700550  102000227    3321       청심경로당  126.950449
# 3  100100124  0017   4  102700551  102000210    3304    원효2동주민센터  126.950904
# 4  100100124  0017   5  102700552  102000212    3306         산천동  126.953984
#
#          Y좌표
# 0  37.534363
# 1  37.533961
# 2  37.533744
# 3  37.534278
# 4  37.535420

# %%
line_names = df_lines['노선명'].unique()
len(line_names)
# Out:
# 659

# %%
for nm in line_names:
    if '6645' in nm:
        print(nm)
# Out:
# 6645

# %%
df_le = df_lines[df_lines['노선명']=='은평01']
df_le
# Out:
#             노선ID   노선명  순번       구간ID      정류소ID  ARS-ID      정류소명  \
# 38811  111900002  은평01   1          0  111900014   12725  연신내역6번출구
# 38812  111900002  은평01   2  111700039  111900012   12733  청구성심병원후문
# 38813  111900002  은평01   3  111702172  111900010   12750  연갈현공판장후문
# 38814  111900002  은평01   4  111700055  111900064   12553  갈현1동주민센터
# 38815  111900002  은평01   5  111700056  111900061   12558      그린마트
# 38816  111900002  은평01   6  111700057  111900055   12563     후레쉬유통
# 38817  111900002  은평01   7  111701038  111900051   12568      미니마트
# 38818  111900002  은평01   8  111702166  111900048   12573       석광사
# 38819  111900002  은평01   9  111700060  111900096   12511      미니마트
# 38820  111900002  은평01  10  111700061  111900091   12517     후레쉬유통
# 38821  111900002  은평01  11  111700062  111900086   12523      그린마트
# 38822  111900002  은평01  12  111702167  111900082   12529  갈현1동주민센터
# 38823  111900002  은평01  13  111702168  111001109   12481    갈현중앙시장
#
# ...

# %%
import folium
map = folium.Map(location=[df_le['Y좌표'].mean(), df_le['X좌표'].mean()], zoom_start=12, tiles='Stamen Toner')

for n in df_le.index[:]:
    # 팝업에 들어갈 텍스트를 지정해 줍니다.
    popup_name = df_le['정류소명'][n]
    # 브랜드명에 따라 아이콘 색상을 달리해서 찍어줍니다.
    icon_color = 'red'
        
    # folium.features.CircleMarker 오류가 날 경우 --> folium.vector_layer.CircleMarker
    folium.CircleMarker(
        location=[df_le['Y좌표'][n], df_le['X좌표'][n]],
        radius=3,
        popup=popup_name,
        color=icon_color,
        fill=True,
        fill_color=icon_color
    ).add_to(map)    

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_le = df_le.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dca1c6628c9b> in <module>
# ----> 1 df_le = df_le.drop(columns=['Unnamed: 0'])
#
# c:\users\sewook kim\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# c:\users\sewook kim\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df_le.columns, df_le.index
# Out:
# (Index(['노선ID', '노선명', '순번', '구간ID', '정류소ID', 'ARS-ID', '정류소명', 'X좌표', 'Y좌표'], dtype='object'),
#  Int64Index([38811, 38812, 38813, 38814, 38815, 38816, 38817, 38818, 38819,
#              38820, 38821, 38822, 38823],
#             dtype='int64'))

# %%
df_psngr.columns, df_psngr.index
# Out:
# (Index(['사용년월', '노선ID', '노선번호', '노선명', '표준버스정류장ID', '버스정류장ARS번호', '역ID', '역명',
#         '00시승차총승객수', '00시하차총승객수', '1시승차총승객수', '1시하차총승객수', '2시승차총승객수',
#         '2시하차총승객수', '3시승차총승객수', '3시하차총승객수', '4시승차총승객수', '4시하차총승객수', '5시승차총승객수',
#         '5시하차총승객수', '6시승차총승객수', '6시하차총승객수', '7시승차총승객수', '7시하차총승객수', '8시승차총승객수',
#         '8시하차총승객수', '9시승차총승객수', '9시하차총승객수', '10시승차총승객수', '10시하차총승객수',
#         '11시승차총승객수', '11시하차총승객수', '12시승차총승객수', '12시하차총승객수', '13시승차총승객수',
#         '13시하차총승객수', '14시승차총승객수', '14시하차총승객수', '15시승차총승객수', '15시하차총승객수',
#         '16시승차총승객수', '16시하차총승객수', '17시승차총승객수', '17시하차총승객수', '18시승차총승객수',
#         '18시하차총승객수', '19시승차총승객수', '19시하차총승객수', '20시승차총승객수', '20시하차총승객수',
#         '21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수', '23시승차총승객수',
#         '23시하차총승객수', '등록일자', 'ARS-ID'],
#        dtype='object'),
#  Int64Index([24726, 24727, 24728, 24729, 24730, 24731, 24732, 24733, 24734,
#              24735, 24736, 24737, 24738],
#             dtype='int64'))

# %%
df_joined = df_psngr.merge(df_le, left_on="표준버스정류장ID", right_on="정류소ID")

# %% [markdown]
# # 그래프 분석

# %%
df_joined
# Out:
#       사용년월    노선ID_x  노선번호           노선명_x  표준버스정류장ID 버스정류장ARS번호      역ID  \
# 0   201909  11110712  은평01  은평01(연신내역~석광사)  111900010      12750  9009785
# 1   201909  11110712  은평01  은평01(연신내역~석광사)  111900012      12733  9009788
# 2   201909  11110712  은평01  은평01(연신내역~석광사)  111900014      12725  9009790
# 3   201909  11110712  은평01  은평01(연신내역~석광사)  111900048      12573  9009892
# 4   201909  11110712  은평01  은평01(연신내역~석광사)  111900051      12568  9009909
# 5   201909  11110712  은평01  은평01(연신내역~석광사)  111900055      12563  9009921
# 6   201909  11110712  은평01  은평01(연신내역~석광사)  111900061      12558  9009944
# 7   201909  11110712  은평01  은평01(연신내역~석광사)  111900064      12553  9009948
# 8   201909  11110712  은평01  은평01(연신내역~석광사)  111900082      12529  9009981
# 9   201909  11110712  은평01  은평01(연신내역~석광사)  111900086      12523  9009985
# 10  201909  11110712  은평01  은평01(연신내역~석광사)  111900091      12517  9009994
# 11  201909  11110712  은평01  은평01(연신내역~석광사)  111900096      12511  9009999
# ...

# %%
type(df_joined['순번'])
# Out:
# pandas.core.series.Series

# %%
df_joined['순번_정류장명'] = df_joined['순번'].astype(str) + "_" + df_joined['역명']

# %%
df_joined['순번_정류장명']
# Out:
# 0      3_연갈현공판장후문
# 1      2_청구성심병원후문
# 2      1_연신내역6번출구
# 3           8_석광사
# 4          7_미니마트
# 5         6_후레쉬유통
# 6          5_그린마트
# 7      4_갈현1동주민센터
# 8     12_갈현1동주민센터
# 9         11_그린마트
# 10       10_후레쉬유통
# 11         9_미니마트
# 12      13_갈현중앙시장
# Name: 순번_정류장명, dtype: object

# %%
df_joined = df_joined.set_index('순번')
df_joined = df_joined.sort_index()

# %%
for i in df_joined.index:
    print(type(df_joined[i:i+1]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
type(df_joined['8시승차총승객수'])
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(20, 5))
plt.xticks(rotation=30)
geton = plt.bar(df_joined['순번_정류장명'], df_joined['8시승차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'], bottom=df_joined['8시승차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'])
# plt.legend((geton[0], getoff[0]), ('BOARD', 'ALIGHT'))
plt.title('8시승차')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.xticks(rotation=30)
geton = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'], bottom=df_joined['8시승차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'])
# plt.legend((geton[0], getoff[0]), ('BOARD', 'ALIGHT'))
plt.title('8시하차')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.xticks(rotation=30)
# geton = plt.bar(df_joined['순번_정류장명'], df_joined['8시승차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'], bottom=df_joined['8시승차총승객수'])
getoff = plt.bar(df_joined['순번_정류장명'], df_joined['16시하차총승객수'])
# plt.legend((geton[0], getoff[0]), ('BOARD', 'ALIGHT'))
plt.title('16시하차')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.xticks(rotation=30)
# geton = plt.bar(df_joined['순번_정류장명'], df_joined['8시승차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'], bottom=df_joined['8시승차총승객수'])
getoff = plt.bar(df_joined['순번_정류장명'], df_joined['16시승차총승객수'])
# plt.legend((geton[0], getoff[0]), ('BOARD', 'ALIGHT'))
plt.title('16시승차')
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.xticks(rotation=30)
# geton = plt.bar(df_joined['순번_정류장명'], df_joined['8시승차총승객수'])
# getoff = plt.bar(df_joined['순번_정류장명'], df_joined['8시하차총승객수'], bottom=df_joined['8시승차총승객수'])
getoff = plt.bar(df_joined['순번_정류장명'], df_joined['16시하차총승객수'])
# plt.legend((geton[0], getoff[0]), ('BOARD', 'ALIGHT'))
plt.title('16시하차')
plt.show()

# %%
plt.figure(figsize=(20, 5))
geton = plt.bar(df_joined['순번_정류장명'], df_joined['19시승차총승객수'])
getoff = plt.bar(df_joined['순번_정류장명'], df_joined['19시하차총승객수'], bottom=df_joined['19시승차총승객수'])
plt.xticks(rotation=90)
plt.legend((geton[0], getoff[0]), ('BOARD', 'ALIGHT'))
plt.title('19시')
plt.show()

# %% [markdown]
# # Predict based on History

# %% [markdown]
# ## Re-structure the data frame

# %%
df_joined

# %%
df_joined = df_joined.drop(columns=['역ID', '노선번호', '노선ID_x'])

# %%
df_train = pd.DataFrame()

year = str(df_joined['사용년월'][1] // 100)
month = str(df_joined['사용년월'][1] % 100)

for i in df_joined.index:
    
    print(df_joined['표준버스정류장ID'][i], type(df_joined['표준버스정류장ID'][i]))
    
    for tm in range(0, 24):
        
        str_geton = f'{tm}시승차총승객수'
        str_getoff = f'{tm}시하차총승객수'
        if tm == 0:
            str_geton = f'{tm:02d}시승차총승객수'
            str_getoff = f'{tm:02d}시하차총승객수'
                        
        tmband = f'{tm:02d}'
        
#         print(year, month, df_joined['표준버스정류장ID'][i], tmband, 
#               df_joined[str_geton][i] + df_joined[str_getoff][i]
#         )
        
        
        
#         df_temp = \
#             pd.DataFrame(
#                 [[year, 
#                 month, 
#                 df_joined['표준버스정류장ID'][i], 
#                 tmband, 
#                 df_joined[str_geton][i] + df_joined[str_getoff][i]]],
#                 columns=list(['year', 'month', 'busstop', 'tmband', 'count'])
#             )
        
#         print(df_temp)

# %%
df_train.dtypes
